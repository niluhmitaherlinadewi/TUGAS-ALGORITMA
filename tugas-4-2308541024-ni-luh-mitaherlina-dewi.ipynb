# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
bakso = ["bakso ikan", "bakso ayam", "bakso sapi", "bakso keju", "bakso mercon"]
print(bakso)
# Out:
# ['bakso ikan', 'bakso ayam', 'bakso sapi', 'bakso keju', 'bakso mercon']

# %%
print(bakso[2])
# Out:
# bakso sapi

# %%
print(bakso[0])
# Out:
# bakso ikan

# %%
print(bakso[-2])
# Out:
# bakso keju

# %%
bakso[3] = "bakso beranak"
print(bakso)
# Out:
# ['bakso ikan', 'bakso ayam', 'bakso sapi', 'bakso beranak', 'bakso mercon']

# %%
bakso[0] = "bakso jumbo"
print(bakso)
# Out:
# ['bakso jumbo', 'bakso ayam', 'bakso sapi', 'bakso beranak', 'bakso mercon']

# %%
print(bakso[1:2])
# Out:
# ['bakso ayam']

# %%
print(bakso[2:4])
# Out:
# ['bakso sapi', 'bakso beranak']

# %%
#tidak merubah list
print(bakso)
# Out:
# ['bakso jumbo', 'bakso ayam', 'bakso sapi', 'bakso beranak', 'bakso mercon']

# %%
#merubah list
bakso[2] = "bakso ikan"
print(bakso)
# Out:
# ['bakso jumbo', 'bakso ayam', 'bakso ikan', 'bakso beranak', 'bakso mercon']

# %%
angka = ('1','2','3','4','5','6','7','8','9')
print(angka)
# Out:
# ('1', '2', '3', '4', '5', '6', '7', '8', '9')

# %%
print(angka[3])
# Out:
# 4

# %%
print(angka[-3])
# Out:
# 7

# %%
print(angka[1:4])
# Out:
# ('2', '3', '4')

# %%
print(angka[0:2])
# Out:
# ('1', '2')

# %%
print(angka[1:-3])
# Out:
# ('2', '3', '4', '5', '6')

# %%
snack = ['Chitato', 'Chitos', 'Lays', 'Nabati']
snack.append('Taro')
print(snack)
# Out:
# ['Chitato', 'Chitos', 'Lays', 'Nabati', 'Taro']

# %%
snack.insert(2,'Momogi')
print(snack)
# Out:
# ['Chitato', 'Chitos', 'Momogi', 'Lays', 'Nabati', 'Taro']

# %%
snack.remove('Nabati')
print(snack)
# Out:
# ['Chitato', 'Chitos', 'Momogi', 'Lays', 'Taro']

# %%
print('Chitato'in snack)
# Out:
# True

# %%
print('Nabati'in snack)
# Out:
# False

# %%
print(len(snack))
# Out:
# 5

# %%
buku = ['cerita','mewarnai','sejarah','berhitung']
for urutan in buku:
    print(urutan)
# Out:
# cerita
# mewarnai
# sejarah
# berhitung

# %%
a = 0
while a < len(buku):
    print(buku[a])
    a+=2
# Out:
# cerita
# sejarah

# %%
x = ['2','4','6','8','10']
for angka_genap in x:
    print(angka_genap)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
y = 1
while y < len(x):
    print(x[y])
    y+=2
# Out:
# 4
# 8

# %%
y = 2
while y < len(x):
    print(x[y])
    y+=1
# Out:
# 6
# 8
# 10

# %%
alat_musik = ['Gitar','Biola','Piano','Drum','Harmonika','Bass']
for urutan in alat_musik:
    print(urutan)
# Out:
# Gitar
# Biola
# Piano
# Drum
# Harmonika
# Bass

# %%
a = 0
while a < len(alat_musik):
    print(alat_musik[a])
    a+=2
# Out:
# Gitar
# Piano
# Harmonika

# %%
huruf = ['a','b','c','d','e','f','g','h']
huruf.append('i')
print(huruf)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
huruf.insert(5,'s')
print(huruf)
# Out:
# ['a', 'b', 'c', 'd', 'e', 's', 'f', 'g', 'h', 'i']

# %%
huruf.remove('s')
print(huruf)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
print('A'in huruf)
# Out:
# False

# %%
print('a'in huruf)
# Out:
# True

# %%
print(len(huruf))
# Out:
# 9

# %%
app =['instagram','tiktok','facebook','whatsapp','youtube','pinterest']
print(app)
# Out:
# ['instagram', 'tiktok', 'facebook', 'whatsapp', 'youtube', 'pinterest']

# %%
print(app[2])
# Out:
# facebook

# %%
print(app[2:1])
# Out:
# []

# %%
print(app[-3])
# Out:
# whatsapp

# %%
app[1] = 'gojek'
print(app)
# Out:
# ['instagram', 'gojek', 'facebook', 'whatsapp', 'youtube', 'pinterest']

# %%
print(app[3:-1])
# Out:
# ['whatsapp', 'youtube']

# %%
tali_24 = ['tali rami', 'tali katun', 'tali nilon', 'tali aramid']
print(tali_24)
# Out:
# ['tali rami', 'tali katun', 'tali nilon', 'tali aramid']

# %%
print(tali_24[3])
# Out:
# tali aramid

# %%
print(tali_24[1:2])
# Out:
# ['tali katun']

# %%
print(tali_24[2:3])
# Out:
# ['tali nilon']
