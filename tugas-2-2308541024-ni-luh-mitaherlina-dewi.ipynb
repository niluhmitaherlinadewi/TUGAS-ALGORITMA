# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama = 'Adi Saputra'
pekerjaan = 'ahli pangan'
tempat_kerja = 'PT GUNA JAYA'
print(nama + ' adalah seorang ' + pekerjaan + ' di ' + tempat_kerja +'.')
# Out:
# Adi Saputra adalah seorang ahli pangan di PT GUNA JAYA.

# %%
print(f'{nama} adalah seorang {pekerjaan} di {tempat_kerja}.')
# Out:
# Adi Saputra adalah seorang ahli pangan di PT GUNA JAYA.

# %%
villa = "Amara Villa"
jumlah_kamar = '3'
alamat = 'Jalan Abdi no 23'
tersedia = 'hair dryer, handuk, teh, kopi, dll'
print(villa + ' adalah villa ' + ' yang berisi ' + jumlah_kamar+ ' kamar ' + ' yang menyediakan ' + tersedia + ' beralamat di ' + alamat + '.')
print("Selamat berliburr!!")
# Out:
# Amara Villa adalah villa  yang berisi 3 kamar  yang menyediakan hair dryer, handuk, teh, kopi, dll beralamat di Jalan Abdi no 23.
# Selamat berliburr!!

# %%
print(f'{villa} beralamat di {alamat}.')
# Out:
# Amara Villa beralamat di Jalan Abdi no 23.

# %%
jenis_snack = 'Chitato'
lahir = '1990'
nama_panjang = 'Chitato Potato Chips'
jenis_makanan = 'makanan ringan'
harga = '12.000'
rasa = 'sapi panggang, keju, ayam panggang, dll'
print(jenis_snack + ' adalah snack yang lahir pada tahun ' +  lahir + ' dan memiliki nama panjang ' + nama_panjang + ' termasuk ' + jenis_makanan + ' dijual dengan harga ' + harga + ' memiliki varian rasa ' + rasa + '.')
# Out:
# Chitato adalah snack yang lahir pada tahun 1990 dan memiliki nama panjang Chitato Potato Chips termasuk makanan ringan dijual dengan harga 12.000 memiliki varian rasa sapi panggang, keju, ayam panggang, dll.

# %%
lagu = 'Aku adalah seorang kapiten yang kuat'
print(lagu[1:2:-2])

# %%
data = 'Mencari rata-rata nilai mahasiswa'
print(data[2:-5])
# Out:
# ncari rata-rata nilai maha

# %%
hobi = 'Hobi saya adalah menari'
print(hobi[1:3])
# Out:
# ob

# %%
logika = 'Ketepatan penalaran'
print(len(logika))
# Out:
# 19

# %%
logika.upper()
# Out:
# 'KETEPATAN PENALARAN'

# %%
logika.lower()
# Out:
# 'ketepatan penalaran'

# %%
logika.find('Ketepatan')
# Out:
# 0

# %%
logika.replace('Ketepatan', 'berpikir')
# Out:
# 'berpikir penalaran'

# %%
logika.replace('Penalaran', 'berpikir')
# Out:
# 'Ketepatan penalaran'

# %%
print('Penalaran' in logika)
# Out:
# False

# %%
print('penalaran' in logika)
# Out:
# True

# %%
print(8+9)
print(45-32)
print(40*80)
print(4/2)
print(88//7)
print(4%2)
print(8**2)
x=6
x-=2
print(x)
x+=5
print(x)
x*=9
print(x)
# Out:
# 17
# 13
# 3200
# 2.0
# 12
# 0
# 64
# 4
# 9
# 81

# %%
x = 4>1
print(x)
x = 1<4
print(x)
x = 4 >= 1
print(x)
x = 1 <= 4
print(x)
x = 4 == 4
print(x)
x = 1 != 5
print(x)
# Out:
# True
# True
# True
# True
# True
# True

# %%
x = 1>4
print(x)
x = 4<1
print(x)
x = 1 >= 4
print(x)
x = 4 <= 1
print(x)
x = 1 == 8
print(x)
x = 1 != 1
print(x)
# Out:
# False
# False
# False
# False
# False
# False

# %%
ayam_goreng = 25
ayam_bakar = 15
print(ayam_goreng > 2 and ayam_bakar < 10)
# Out:
# False

# %%
print(ayam_goreng > 26 or ayam_bakar < 20)
# Out:
# True

# %%
print(not ayam_goreng < 10)
# Out:
# True

# %%
baju = 10
celana = 5
rok = 2
jaket = 5
print(baju > rok and celana < jaket)
# Out:
# False

# %%
print(rok > celana or jaket < celana)
# Out:
# False

# %%
print(not rok > baju)
# Out:
# True

# %%
a = 12
b = 24
c = 16
print(a < 18 and c > 10)
# Out:
# True

# %%
print(b < c or a > b)
# Out:
# False

# %%
print(not a > 7)
# Out:
# False
