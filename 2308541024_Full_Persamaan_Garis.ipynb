# %%
# PERSAMAAN GARIS JIKA DIKETAHUI NILAI 2 TITIK
# Garis pertama yang melewati (a,b) dan (c,d)
# Garis kedua yang melewati (e,f) dan (g,h)
# Maka terdapat 3 kemungkinan dari kedua persamaan garis ini, yaitu:
# 1. Terdapat perpotongan di satu titik (m1 != m2 )
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) atau (kedua garis sejajar)
# 3. Tidak terdapat solusi (tidak terdapat perpotongan garis) atau (kedua garis sejajar)

# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt

# Masukkan titik garis pertama (a,b) dan (c,d)
m_24 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
i_24 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
t_24 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
a_24 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

# Masukkan titik garis kedua (e,f) dan (g,h)
h_24 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
e_24 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
r_24 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
l_24 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

# Gradien garis pertama
m1_24 = (a_24-i_24)/(t_24-m_24)
# Gradien garis kedua
m2_24 = (l_24-e_24)/(r_24-h_24)

# Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
# Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

# Titik potong garis pertama terhadap sumbu y
c1_24 = -m1_24*m_24+i_24
# Titik potong garis kedua terhadap sumbu y garis kedua
c2_24 = -m2_24*h_24+e_24
print("Persamaan garis pertama adalah y={}x+{}".format(m1_24,c1_24))
print("Persamaan garis kedua adalah y={}x+{}".format(m2_24,c2_24))

if m1_24==m2_24:
    #print("Ada 2 kemungkinan yang terjadi : Terdapat tak hingga banyaknya solusi atau Tidak terdapat solusi ")
    if c1_24 == c2_24:
        print("Waww, ternyata garisnya berhimpit!! ")
        x_24=np.linspace(-9,9,100)
        plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='green')
        plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='yellow')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah grafiknya')
        plt.show()
    else:
        print("Waww, garisnya sejajar sehingga tidak ada solusi")
        x_24=np.linspace(-9,9,100)
        plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='blue')
        plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='red')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah grafiknya')
        plt.show()
else:
    print("Nahhh, garisnya berpotongan sehingga akan ada titik potongnya")
    tp_x_24 = (-m2_24*h_24+e_24+m1_24*m_24-i-24)/(m1_24-m2_24)
    tp_y_24 = m1_24*(tp_x_24-m_24)+i_24
    print("Titik potong kedua garis yaitu ({},{})".format(tp_x_24,tp_y_24))

    x_24=np.linspace(tp_x_24-9,tp_x_24+9,100)
    plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='purple')
    plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='green')
    plt.plot(tp_x_24,tp_y_24,color='black',marker='o',markersize=5)
    plt.axvline(x=0,color='black')
    plt.axhline(y=0,color='black')
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.title('Inilah grafiknya')

    plt.show()
# Out:
# Nilai x dari titik pertama dari garis pertama adalah 1
# Nilai y dari titik pertama dari garis pertama adalah 2
# Nilai x dari titik kedua dari garis pertama adalah 3
# Nilai y dari titik kedua dari garis pertama adalah 4
# Nilai x dari titik pertama dari garis kedua adalah 1
# Nilai y dari titik pertama dari garis kedua adalah 3
# Nilai x dari titik kedua dari garis kedua adalah 5
# Nilai y dari titik kedua dari garis kedua adalah 7
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Persamaan garis pertama adalah y=1.0x+1.0
# Persamaan garis kedua adalah y=1.0x+2.0
# Waww, garisnya sejajar sehingga tidak ada solusi

# %%
# PERSAMAAN GARIS JIKA DIKETAHUI NILAI 2 TITIK
# Garis pertama yang melewati (a,b) dan (c,d)
# Garis kedua yang melewati (e,f) dan (g,h)
# Maka terdapat 3 kemungkinan dari kedua persamaan garis ini, yaitu:
# 1. Terdapat perpotongan di satu titik (m1 != m2 )
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) atau (kedua garis sejajar)
# 3. Tidak terdapat solusi (tidak terdapat perpotongan garis) atau (kedua garis sejajar)

# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt

# Masukkan titik garis pertama (a,b) dan (c,d)
m_24 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
i_24 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
t_24 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
a_24 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

# Masukkan titik garis kedua (e,f) dan (g,h)
h_24 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
e_24 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
r_24 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
l_24 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

# Gradien garis pertama
m1_24 = (a_24-i_24)/(t_24-m_24)
# Gradien garis kedua
m2_24 = (l_24-e_24)/(r_24-h_24)

# Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
# Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

# Titik potong garis pertama terhadap sumbu y
c1_24 = -m1_24*m_24+i_24
# Titik potong garis kedua terhadap sumbu y garis kedua
c2_24 = -m2_24*h_24+e_24
print("Persamaan garis pertama adalah y={}x+{}".format(m1_24,c1_24))
print("Persamaan garis kedua adalah y={}x+{}".format(m2_24,c2_24))

if m1_24==m2_24:
    #print("Ada 2 kemungkinan yang terjadi : Terdapat tak hingga banyaknya solusi atau Tidak terdapat solusi ")
    if c1_24 == c2_24:
        print("Waww, ternyata garisnya berhimpit!! ")
        x_24=np.linspace(-9,9,100)
        plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='green')
        plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='yellow')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah grafiknya')
        plt.show()
    else:
        print("Waww, garisnya sejajar sehingga tidak ada solusi")
        x_24=np.linspace(-9,9,100)
        plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='blue')
        plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='red')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah grafiknya')
        plt.show()
else:
    print("Nahhh, garisnya berpotongan sehingga akan ada titik potongnya")
    tp_x_24 = (-m2_24*h_24+e_24+m1_24*m_24-i_24)/(m1_24-m2_24)
    tp_y_24 = m1_24*(tp_x_24-m_24)+i_24
    print("Titik potong kedua garis yaitu ({},{})".format(tp_x_24,tp_y_24))

    x_24=np.linspace(tp_x_24-9,tp_x_24+9,100)
    plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='purple')
    plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='green')
    plt.plot(tp_x_24,tp_y_24,color='black',marker='o',markersize=5)
    plt.axvline(x=0,color='black')
    plt.axhline(y=0,color='black')
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.title('Inilah grafiknya')

    plt.show()
# Out:
# Nilai x dari titik pertama dari garis pertama adalah -1
# Nilai y dari titik pertama dari garis pertama adalah 1
# Nilai x dari titik kedua dari garis pertama adalah 3
# Nilai y dari titik kedua dari garis pertama adalah 2
# Nilai x dari titik pertama dari garis kedua adalah 0
# Nilai y dari titik pertama dari garis kedua adalah 2
# Nilai x dari titik kedua dari garis kedua adalah 2
# Nilai y dari titik kedua dari garis kedua adalah 4
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Persamaan garis pertama adalah y=0.25x+1.25
# Persamaan garis kedua adalah y=1.0x+2.0
# Nahhh, garisnya berpotongan sehingga akan ada titik potongnya
# Titik potong kedua garis yaitu (-1.0,1.0)

# %%
# PERSAMAAN GARIS JIKA DIKETAHUI NILAI 2 TITIK
# Garis pertama yang melewati (a,b) dan (c,d)
# Garis kedua yang melewati (e,f) dan (g,h)
# Maka terdapat 3 kemungkinan dari kedua persamaan garis ini, yaitu:
# 1. Terdapat perpotongan di satu titik (m1 != m2 )
# 2. Terdapat tak berhingga banyaknya solusi (kedua garis berhimpitan) atau (kedua garis sejajar)
# 3. Tidak terdapat solusi (tidak terdapat perpotongan garis) atau (kedua garis sejajar)

# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt

# Masukkan titik garis pertama (a,b) dan (c,d)
m_24 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
i_24 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
t_24 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
a_24 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

# Masukkan titik garis kedua (e,f) dan (g,h)
h_24 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
e_24 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
r_24 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
l_24 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

# Gradien garis pertama
m1_24 = (a_24-i_24)/(t_24-m_24)
# Gradien garis kedua
m2_24 = (l_24-e_24)/(r_24-h_24)

# Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
# Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

# Titik potong garis pertama terhadap sumbu y
c1_24 = -m1_24*m_24+i_24
# Titik potong garis kedua terhadap sumbu y garis kedua
c2_24 = -m2_24*h_24+e_24
print("Persamaan garis pertama adalah y={}x+{}".format(m1_24,c1_24))
print("Persamaan garis kedua adalah y={}x+{}".format(m2_24,c2_24))

if m1_24==m2_24:
    #print("Ada 2 kemungkinan yang terjadi : Terdapat tak hingga banyaknya solusi atau Tidak terdapat solusi ")
    if c1_24 == c2_24:
        print("Waww, ternyata garisnya berhimpit!! ")
        x_24=np.linspace(-9,9,100)
        plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='green')
        plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='yellow')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah grafiknya')
        plt.show()
    else:
        print("Waww, garisnya sejajar sehingga tidak ada solusi")
        x_24=np.linspace(-9,9,100)
        plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='blue')
        plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='red')
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah grafiknya')
        plt.show()
else:
    print("Nahhh, garisnya berpotongan sehingga akan ada titik potongnya")
    tp_x_24 = (-m2_24*h_24+e_24+m1_24*m_24-i_5624)/(m1_24-m2_24)
    tp_y_24 = m1_24*(tp_x_24-m_24)+i_24
    print("Titik potong kedua garis yaitu ({},{})".format(tp_x_24,tp_y_24))

    x_24=np.linspace(tp_x_24-9,tp_x_24+9,100)
    plt.plot(x_24,m1_24*(x_24-m_24)+i_24,color='purple')
    plt.plot(x_24,m2_24*(x_24-h_24)+e_24,color='green')
    plt.plot(tp_x_24,tp_y_24,color='black',marker='o',markersize=5)
    plt.axvline(x=0,color='black')
    plt.axhline(y=0,color='black')
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.title('Inilah grafiknya')

    plt.show()
# Out:
# Nilai x dari titik pertama dari garis pertama adalah 1
# Nilai y dari titik pertama dari garis pertama adalah 2
# Nilai x dari titik kedua dari garis pertama adalah 2
# Nilai y dari titik kedua dari garis pertama adalah 3
# Nilai x dari titik pertama dari garis kedua adalah 4
# Nilai y dari titik pertama dari garis kedua adalah 5
# Nilai x dari titik kedua dari garis kedua adalah 5
# Nilai y dari titik kedua dari garis kedua adalah 6
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Persamaan garis pertama adalah y=1.0x+1.0
# Persamaan garis kedua adalah y=1.0x+1.0
# Waww, ternyata garisnya berhimpit!!

# %%
# PERSAAMAAN GARIS JIKA DIKETAHUI GRADIEN DAN TITIK YANG DILEWATI
# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
m1_24 = float(input("Gradien dari garis pertama adalah: "))
m_24 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
i_24 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (c,d)
m2_24 = float(input("Gradien dari garis kedua adalah: "))
t_24 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
a_24 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_24 = -m1_24*m_24+i_24
c2_24 = -m2_24*t_24+a_24

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_24 == m2_24:
      # print("Kedua garis sejajar ")
        if c1_24 == c2_24:
            print("Waww, ternyata garisnya berhimpit!!")
        else:
            print("Waww, garisnya sejajar sehingga tidak ada solusi")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_24 = m1_24*(x_24-m_24)+ i_24
        y2_24 = m2_24*(x_24-t_24) + a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='green')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='red')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        x_intersect = (c2_24 - c1_24) / (m1_24 - m2_24)
        y_intersect = m1_24 * (x_intersect - m_24) + i_24
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(x_intersect, y_intersect))

        # Plotting the lines
        x_24 = np.linspace(x_intersect-10, x_intersect+10, 400)
        y1_24 = m1_24*(x_24-m_24)+i_24
        y2_24 = m2_24*(x_24-t_24)+a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='red')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='blue')
        plt.scatter(x_intersect, y_intersect, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
# Out:
# Gradien dari garis pertama adalah: 1
# Nilai x dari titik yang dilewati oleh garis pertama adalah: 0
# Nilai y dari titik yang dilewati oleh garis pertama adalah: 0
# Gradien dari garis kedua adalah: 1
# Nilai x dari titik yang dilewati oleh garis kedua adalah: 2
# Nilai y dari titik yang dilewati oleh garis kedua adalah: 2
# Waww, ternyata garisnya berhimpit!!

# %%
# Persamaan Garis Jika Diketahui Gradien dan Titik yang dilewati
# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
m1_24 = float(input("Gradien dari garis pertama adalah: "))
m_24 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
i_24 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (c,d)
m2_24 = float(input("Gradien dari garis kedua adalah: "))
t_24 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
a_24 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_24 = -m1_24*m_24+i_24
c2_24 = -m2_24*t_24+a_24

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_24 == m2_24:
      # print("Kedua garis sejajar ")
        if c1_24 == c2_24:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_24 = m1_24*(x_24-m_24)+ i_24
        y2_24 = m2_24*(x_24-t_24) + a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='green')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='red')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        x_intersect = (c2_24 - c1_24) / (m1_24 - m2_24)
        y_intersect = m1_24 * (x_intersect - m_24) + i_24
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(x_intersect, y_intersect))

        # Plotting the lines
        x_24 = np.linspace(x_intersect-10, x_intersect+10, 400)
        y1_24 = m1_24*(x_24-m_24)+i_24
        y2_24 = m2_24*(x_24-t_24)+a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='red')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='blue')
        plt.scatter(x_intersect, y_intersect, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
# Out:
# Gradien dari garis pertama adalah: 2
# Nilai x dari titik yang dilewati oleh garis pertama adalah: 1
# Nilai y dari titik yang dilewati oleh garis pertama adalah: 3
# Gradien dari garis kedua adalah: 2
# Nilai x dari titik yang dilewati oleh garis kedua adalah: 3
# Nilai y dari titik yang dilewati oleh garis kedua adalah: 1
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.

# %%
# Persamaan Garis Jika Diketahui Gradien dan Titik yang dilewati
# Memanggil numpy
import numpy as np
# Memanggil matplotlib.pyplot
import matplotlib.pyplot as plt

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
m1_24 = float(input("Gradien dari garis pertama adalah: "))
m_24 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
i_24 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (c,d)
m2_24 = float(input("Gradien dari garis kedua adalah: "))
t_24 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
a_24 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_24 = -m1_24*m_24+i_24
c2_24 = -m2_24*t_24+a_24

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_24 == m2_24:
      # print("Kedua garis sejajar ")
        if c1_24 == c2_24:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_24 = m1_24*(x_24-m_24)+ i_24
        y2_24 = m2_24*(x_24-t_24) + a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='green')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='red')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        x_intersect = (c2_24 - c1_24) / (m1_24 - m2_24)
        y_intersect = m1_24 * (x_intersect - m_24) + i_24
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(x_intersect, y_intersect))

        # Plotting the lines
        x_24 = np.linspace(x_intersect-10, x_intersect+10, 400)
        y1_24 = m1_24*(x_24-m_24)+i_24
        y2_24 = m2_24*(x_24-t_24)+a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='red')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='blue')
        plt.scatter(x_intersect, y_intersect, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
# Out:
# Gradien dari garis pertama adalah: 2
# Nilai x dari titik yang dilewati oleh garis pertama adalah: 1
# Nilai y dari titik yang dilewati oleh garis pertama adalah: 3
# Gradien dari garis kedua adalah: 3
# Nilai x dari titik yang dilewati oleh garis kedua adalah: 2
# Nilai y dari titik yang dilewati oleh garis kedua adalah: 5
# Titik potong kedua garis adalah (2.000,5.000)

# %%
import numpy as np
import matplotlib.pyplot as plt

kasus = float(input("Kasus berapakah yang akan dikerjakan? "))

if kasus == 1:
    # Masukkan titik garis pertama (a,b) dan (c,d)
    m_24 = float(input("Nilai x dari titik pertama dari garis pertama adalah "))
    i_24 = float(input("Nilai y dari titik pertama dari garis pertama adalah "))
    t_24 = float(input("Nilai x dari titik kedua dari garis pertama adalah "))
    a_24 = float(input("Nilai y dari titik kedua dari garis pertama adalah "))

    # Masukkan titik garis kedua (e,f) dan (g,h)
    h_24 = float(input("Nilai x dari titik pertama dari garis kedua adalah "))
    e_24 = float(input("Nilai y dari titik pertama dari garis kedua adalah "))
    r_24 = float(input("Nilai x dari titik kedua dari garis kedua adalah "))
    l_24 = float(input("Nilai y dari titik kedua dari garis kedua adalah "))

    # Gradien garis pertama
    m1_24 = (a_24 - i_24) / (t_24 - m_24)
    # Gradien garis kedua
    m2_24 = (l_24 - e_24) / (r_24 - h_24)

    # Persamaan garis pertama adalah y=m1(x-a)+b => m1*x-m1*a+b
    # Persamaan garis kedua adalah y=m2(x-e)+f => m2*x-m2*e+f

    # Titik potong garis pertama terhadap sumbu y
    c1_24 = -m1_24 * m_24 + i_24
    # Titik potong garis kedua terhadap sumbu y garis kedua
    c2_24 = -m2_24 * h_24 + e_24

    print("Persamaan garis pertama adalah y={}x+{}".format(m1_24, c1_24))
    print("Persamaan garis kedua adalah y={}x+{}".format(m2_24, c2_24))

    if m1_24 == m2_24:
        # print("Kedua garis sejajar sehingga kemungkinan yang terjadi adalah tidak terdapat solusi atau terdapat tidak berhingga banyaknya solusi")
        if c1_24 == c2_24:
            print("Kedua garis akan berhimpitan sehingga terdapat tidak berhingga banyaknya solusi")
            x_24 = np.linspace(-9, 9, 100)
            plt.plot(x_24, m1_24 * (x_24 - m_24) + i_24, color='green')
            plt.plot(x_24, m2_24 * (x_24 - h_24) + e_24, color='yellow')
            plt.show()
        else:
            print("Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi")
            x_24 = np.linspace(-10, 10, 100)
            plt.plot(x_24, m1_24 * (x_24 - m_24) + i_24, color='blue')
            plt.plot(x_24, m2_24 * (x_24 - h_24) + e_24, color='red')
            plt.show()
    else:
        print("Terdapat satu titik potong")
        tp_x_24 = (-m2_24 * h_24 + e_24 + m1_24 * m_24 - i_24) / (m1_24 - m2_24)
        tp_y_24 = m1_24 * (tp_x_24 - m_24) + i_24
        print("Titik potong kedua garis yaitu ({},{})".format(tp_x_24, tp_y_24))

        x_24 = np.linspace(tp_x_24 - 10, tp_x_24 + 10, 100)
        plt.plot(x_24, m1_24 * (x_24 - m_24) + i_24, color='purple')
        plt.plot(x_24, m2_24 * (x_24 - h_24) + e_24, color='green')
        plt.plot(tp_x_24, tp_y_24, color='black', marker='o', markersize=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.show()

elif kasus == 2:
    # Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (a,b)
    m1_24 = float(input("Gradien dari garis pertama adalah: "))
    m_24 = float(input("Nilai x dari titik yang dilewati oleh garis pertama adalah: "))
    i_24 = float(input("Nilai y dari titik yang dilewati oleh garis pertama adalah: "))

    # Masukkan nilai gradien persamaan garis kedua dan titik yang diketahui (c,d)
    m2_24 = float(input("Gradien dari garis kedua adalah: "))
    t_24 = float(input("Nilai x dari titik yang dilewati oleh garis kedua adalah: "))
    a_24 = float(input("Nilai y dari titik yang dilewati oleh garis kedua adalah: "))

    # Menghitung konstanta dari masing-masing persamaan garis
    c1_24 = -m1_24 * m_24 + i_24
    c2_24 = -m2_24 * t_24 + a_24

    # Memeriksa apakah kedua garis sejajar atau tidak
    if m1_24 == m2_24:
        # print("Kedua garis sejajar ")
        if c1_24 == c2_24:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Format garis
        x_24 = np.linspace(-10, 10, 400)
        y1_24 = m1_24 * (x_24 - m_24) + i_24
        y2_24 = m2_24 * (x_24 - t_24) + a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='green')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='red')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
    else:
        # Menghitung titik potong dari kedua garis
        tp_x_24 = (c2_24 - c1_24) / (m1_24 - m2_24)
        tp_y_24= m1_24 * (x_intersect - m_24) + i_24
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_24, tp_y_24))

        # Format garis
        x_24 = np.linspace(tp_x_24 - 10, tp_x_24 + 10, 400)
        y1_24 = m1_24 * (x_24 - m_24) + i_24
        y2_24 = m2_24 * (x_24 - t_24) + a_24
        plt.plot(x_24, y1_24, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_24, m_24, i_24), color='red')
        plt.plot(x_24, y2_24, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_24, t_24, a_24), color='blue')
        plt.scatter(tp_x_24, tp_y_24, color='green', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

elif kasus == 3:
    # Masukkan nilai koefisien dan konstanta
    print("Garis pertama yang memenuhi persamaan berbentuk ax + by = c ")
    m_24 = float(input("Koefisien dari x pada garis pertama adalah "))
    i_24 = float(input("Koefisien dari y pada garis pertama adalah "))
    t_24 = float(input("Konstanta dari garis pertama adalah "))

    print("Garis kedua yang memenuhi persamaan berbentuk dx + ey = f ")
    h_24 = float(input("Koefisien dari x pada garis kedua adalah "))
    e_24 = float(input("Koefisien dari y pada garis kedua adalah "))
    r_24 = float(input("Konstanta dari garis kedua adalah "))
    # Menghitung determinan utama
    D_24 = m_24*e_24 - i_24*h_24

    if D_24 == 0:
        print ("Garis-garis akan berimpit, sehingga persamaan garis memiliki tak berhingga solusi.")
         # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (t_24 - m_24* x_vals) / i_24
        y_vals2 = (r_24 - h_24 * x_vals) / e_24

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{m_24}x + {i_24}y = {t_24}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{h_24}x + {e_24}y = {r_24}')

        # Plot titik potong
        plt.plot(x_24, y_24, 'go')  # 'go' means greeen color, circle marker
        plt.text(x_24, y_24, f'({x_24:.2f}, {y_24:.2f})', fontsize=12, ha='left')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

    else:
        # Menghitung determinan untuk x dan y
        Dx_24 = t_24*e_24 - i_24*r_24
        Dy_24 = m_24*r_24 - t_24*h_24
        # Menemukan solusi untuk x dan y
        x_24 = Dx_24 /D_24
        y_24 = Dy_24 /D_24
        print(f"Titik potong dari dua garis adalah: x = {x_24}, y = {y_24}")
        # Menyiapkan data untuk plotting
        x_vals = np.linspace(-10, 10, 400)
        y_vals1 = (t_24 - m_24* x_vals) / i_24
        y_vals2 = (r_24 - h_24 * x_vals) / e_24

        # Plot garis pertama
        plt.plot(x_vals, y_vals1, label=f'{m_24}x + {i_24}y = {t_24}')

        # Plot garis kedua
        plt.plot(x_vals, y_vals2, label=f'{h_24}x + {e_24}y = {r_24}')

        # Plot titik potong
        plt.plot(x_24, y_24, 'go')  # 'go' means green color, circle marker
        plt.text(x_24, y_24, f'({x_24:.2f}, {y_24:.2f})', fontsize=12, ha='left')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()

else:
  print('Tidak ada solusi ')
# Out:
# Kasus berapakah yang akan dikerjakan? 3
# Garis pertama yang memenuhi persamaan berbentuk ax + by = c
# Koefisien dari x pada garis pertama adalah 1
# Koefisien dari y pada garis pertama adalah 2
# Konstanta dari garis pertama adalah 3
# Garis kedua yang memenuhi persamaan berbentuk dx + ey = f
# Koefisien dari x pada garis kedua adalah 2
# Koefisien dari y pada garis kedua adalah 3
# Konstanta dari garis kedua adalah 6
# Titik potong dari dua garis adalah: x = 3.0, y = -0.0

# %%
#SOLUSI KASUS 3 MENGGUNAKAN MATRIKS
# Memanggil numpy
import numpy as np
# Memanggil pyplot
import matplotlib.pyplot as plt

# Masukkan nilai koefisien dan konstanta
print("Garis pertama yang memenuhi persamaan berbentuk ax + by = c ")
m_24 = float(input("Koefisien dari x pada garis pertama adalah "))
i_24 = float(input("Koefisien dari y pada garis pertama adalah "))
t_24 = float(input("Konstanta dari garis pertama adalah "))

print("Garis kedua yang memenuhi persamaan berbentuk dx + ey = f ")
h_24 = float(input("Koefisien dari x pada garis kedua adalah "))
e_24 = float(input("Koefisien dari y pada garis kedua adalah "))
r_24 = float(input("Konstanta dari garis kedua adalah "))


def solve_linear_equations(m_24,i_24,t_24,h_24,e_24,r_24):
    # Membuat bentuk matriks dari koefisien
    M_24 = np.array([[m_24, i_24],
                  [h_24, e_24]])

    # Membuat bentuk matriks konstanta
    I_24 = np.array([t_24, r_24])

    # Hitung determinan dari matriks M
    det_M_24 = np.linalg.det(M_24)

    if det_M_24 != 0:
        # Satu Solusi
        solution = np.linalg.solve(M_24, I_24)
        result = f"Satu Solusi: x = {solution[0]}, y = {solution[1]}"
        plot_lines_and_solution(m_24,i_24,t_24,h_24,e_24,r_24,solution)
        return result
    else:
        # Memastikan sistem
        augmented_matrix_24 = np.array([[m_24, i_24, t_24],
                                     [h_24, e_24, r_24]])
        rank_M_24 = np.linalg.matrix_rank(M_24)
        rank_augmented_24 = np.linalg.matrix_rank(augmented_matrix_24)

        if rank_M_24 == rank_augmented_24:
            result = "Tak terhingga solusi"
            plot_lines_and_solution(m_24,i_24,t_24,h_24,e_24,r_24,None)
            return result
        else:
            result = "Tidak terdapat solusi"
            plot_lines_and_solution(m_24,i_24,t_24,h_24,e_24,r_24,None)
            return result_

def plot_lines_and_solution(m_24,i_24,t_24,h_24,e_24,r_24,solution):
    # Tentukan range nilai x
    x_values_24 = np.linspace(-10, 10, 400)

    # Hitung nilai y masing-masing persamaan
    y1_values_24 = (t_24 - m_24 * x_values_24) / i_24
    y2_values_24 = (r_24 - h_24 * x_values_24) / e_24

    plt.figure(figsize=(6, 4))

    # Plot garis pertama
    plt.plot(x_values_24, y1_values_24, label=f'{m_24}x + {i_24}y = {t_24}')

    # Plot garis kedua
    plt.plot(x_values_24, y2_values_24, label=f'{h_24}x + {e_24}y = {r_24}')

    # Jika ada satu solusi maka terdapat titik potong
    if solution is not None:
        plt.plot(solution[0], solution[1], 'go')  # Titik potong berwarna hijau
        plt.annotate(f'({solution[0]:.2f}, {solution[1]:.2f})', xy=(solution[0], solution[1]), xytext=(solution[0] + 1, solution[1]))

    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Inilah garfiknya')
    plt.show()


result = solve_linear_equations(m_24,i_24,t_24,h_24,e_24,r_24)
print(result)
# Out:
# Garis pertama yang memenuhi persamaan berbentuk ax + by = c
# Koefisien dari x pada garis pertama adalah 1
# Koefisien dari y pada garis pertama adalah 2
# Konstanta dari garis pertama adalah 3
# Garis kedua yang memenuhi persamaan berbentuk dx + ey = f
# Koefisien dari x pada garis kedua adalah 2
# Koefisien dari y pada garis kedua adalah 3
# Konstanta dari garis kedua adalah 6
# Satu Solusi: x = 3.0, y = 0.0
