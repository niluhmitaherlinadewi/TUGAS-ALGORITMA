# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
soto_ayam_terjual = input("Berapakah jumlah soto ayam yang sudah terjual? ")
soto_ayam_belum_terjual = input("Berapakah jumlah soto ayam yang belum terjual? ")
total_soto_ayam = int(soto_ayam_terjual) + int(soto_ayam_belum_terjual)
print("Total soto ayam yang dibuat hari ini adalah Rp "+ str(total_soto_ayam))
# Out:
# Berapakah jumlah soto ayam yang sudah terjual?  60
# Berapakah jumlah soto ayam yang belum terjual?  45
# Total soto ayam yang dibuat hari ini adalah Rp 105

# %%
jumlah_villa = 30
uang_sewa = 2000000
print(jumlah_villa)
print(uang_sewa)
print(jumlah_villa*uang_sewa)
# Out:
# 30
# 2000000
# 60000000

# %%
a = {1,6,8,10}
b = {3,5,7,9}
c = input("Hasil penjumlahan a dan b adalah")
# Out:
# Hasil penjumlahan a dan b adalah {4,11,15,19}

# %%
1,2,2,2,3,4,4,4,5,5,5,5,5,6
i = input("Modus data di atas adalah")
# Out:
# Modus data di atas adalah 5

# %%
hari = ("senin,selasa,rabu,kamis,jumat,sabtu,minggu")
bulan = (", januari,februari,maret,april,mei")

gabungan_hari_bulan = hari + bulan
gabungan_hari_bulan
# Out:
# 'senin,selasa,rabu,kamis,jumat,sabtu,minggu, januari,februari,maret,april,mei'

# %%
i = 6 + 6
ii = 3
iii = i/ii
print(iii)
# Out:
# 4.0

# %%
str("Hari ini makan nasi padang")
# Out:
# 'Hari ini makan nasi padang'

# %%
bool("50 kg besi = 50 kg kapas")
# Out:
# True

# %%
float(3300-23230)
# Out:
# -19930.0

# %%
a = 2**4
b = 3**3
print(a-b)
# Out:
# -11

# %%
(121+23)/24-6
# Out:
# 0.0

# %%
jari_jari_lingkaran = 7
luas_lingkaran = 22/7*7**2
print(luas_lingkaran)
# Out:
# 154.0

# %%
harga_buku = 10000
jumlah_buku = 20
harga_pensil = 2000
jumlah_pensil = 10
total_belanja = harga_buku*jumlah_buku + harga_pensil*jumlah_pensil
print(total_belanja)
# Out:
# 220000

# %%
alas_segitiga = 3
tinggi_segitiga = 6
tinggi_prisma = 10
luas_alas = 1/2*alas_segitiga*tinggi_segitiga
volume_prisma_segitiga = luas_alas*tinggi_prisma
print(luas_alas)
print(volume_prisma_segitiga)
# Out:
# 9.0
# 90.0

# %%
p = 3
q = 4
r = p*2 + q*2/2
print(r)
# Out:
# 10.0

# %%
|
